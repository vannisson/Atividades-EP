# %% [markdown]
# # Atividade 3
# A tabela Z utilizada nessa atividade foi disponibilizada pelo professor da matéria.
#
# O link para acesso da tabela utilizada é: https://github.com/vannisson/Atv-EP/blob/main/tables/tabela-z.csv

# %%
# Importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## 1° Questão:
# Seja X : N(100, 25). Calcule usando a tabela da distribuição normal

# %%
# Definindo os valores:
media = 100
desvio = 25
quantidade = 500
numeros = np.random.normal(media,desvio,quantidade)

plt.plot(numeros)
plt.title("Distribuição Normal")
plt.show()

# %%
# Agora plotando a distribuição dos dados
sns.distplot(numeros, hist=False,rug=False)
plt.title('Distribuição Normal')
plt.xlim(-50,250)
plt.axvline(media,color='k')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Agora resolvendo as alternativas:
# * P(100 ≤ X ≤ 106)

# %%
# Descobrindo o ZScore
zscore1 = (100 - media)/desvio
zscore2 = (106 - media)/desvio
# O zscore1(0) é equivalente a 0.5 na tabela
# O zscore2(0.24) é equivalente a 0.59483 na tabela
prob1 = 0.5
prob2 = 0.59483
# Agora é só subtrair para descobrir a área no intervalo
resultado = prob2 - prob1
resultado
# Out:
# 0.09482999999999997

# %% [markdown]
# * P(89 ≤ X ≤ 107)

# %%
# Descobrindo o ZScore
zscore1 = (89 - media)/desvio
zscore2 = (107 - media)/desvio
# O zscore1(-0.44) é equivalente a 0.32997 na tabela
# O zscore2(0.28) é equivalente a 0.61026 na tabela
prob1 = 0.32997
prob2 = 0.61026
# Agora é só subtrair para descobrir a área no intervalo
resultado = prob2 - prob1
resultado
# Out:
# 0.28029000000000004

# %% [markdown]
# * P(112 ≤ X ≤ 116)

# %%
# Descobrindo o ZScore
zscore1 = (112 - media)/desvio
zscore2 = (116 - media)/desvio
# O zscore1(0.48) é equivalente a 0.68439 na tabela
# O zscore2(0.64) é equivalente a 0.73565 na tabela
prob1 = 0.68439
prob2 = 0.73565
# Agora é só subtrair para descobrir a área no intervalo
resultado = prob2 - prob1
resultado
# Out:
# 0.05125999999999997

# %% [markdown]
# * P(X ≥ 108)

# %%
# # Descobrindo o ZScore
zscore1 = (108 - media)/desvio
# O zscore1(0.32) é equivalente a 0.62552 na tabela
resultado = 1 - 0.62552
# Subtraimos por 1 pois queremos valores acima de 0.62552
resultado
# Out:
# 0.37448000000000004

# %% [markdown]
# ## 2° Questão
# Sendo X : N(50, 16), determine X a , tal que:

# %%
# Definindo os valores
media = 50
desvio = 16
quantidade = 500
numeros = np.random.normal(media,desvio,quantidade)
# Agora plotando a distribuição dos dados
sns.distplot(numeros, hist=False,rug=False)
plt.title('Distribuição Normal')
plt.xlim(-50,150)
plt.axvline(media,color='k')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# * P(X ≥ X a ) = 0.05

# %%
# Se a probabilidade é 0.05 e X > ou = Xa, então 1 - y = 0.05, ou seja y = 0.95
# Agora que sabemos qual o valor de y, vamos ver o valor na tabela que mais se aproxima de 0.95, ou seja, 0.95053(1.65)
# Convertendo para a fórmula de Zscore:
x = (1.65 * desvio) + media
print("O valor de Xa é",x)
# Out:
# O valor de X é 76.4

# %% [markdown]
# * P(X ≤ X a ) = 0.99

# %%
# Se a probabilidade é de 0.99 e X < ou = Xa, vamos ver qual valor se aproxima mais na tabela
# O valor que mais se aproxima é 0.99010 (2.33)
# Convertendo para a fórmula de Zscore
x = (2.33 * desvio) + media
print("O valor de Xa é",x)
# Out:
# O valor de Xa é 87.28

# %% [markdown]
# ## 3° Questão
# Um fabricante de baterias sabe, por experiência passada, que as
# baterias de sua faricação têm vida média de 600 dias e desvio padrão
# de 100, sendo que a duração tem aproximadamente distribuição
# normal. Oferece uma garantia de 312 dias, isto é, troca as baterias
# que apresentarem falhas nesse perı́odo. Fabrica 10.000 baterias
# mensalmente. Quantas deverá trocar pelo uso da garantia,
# mensalmente?

# %%
media = 600
desvio = 100
quantidade = 10000
numeros = np.random.normal(media,desvio,quantidade)
# Agora plotando a distribuição dos dados
sns.distplot(numeros, hist=False,rug=False)
plt.title('Distribuição Normal')
plt.xlim(0,1200)
plt.axvline(media,color='k')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Após plotar os dados, faremos o cálculo:

# %%
zscore = (312-media)/desvio
# O valor de zscore é -2.88 (0.00199)
probabilidade = 0.00199
# Agora que temos a probabilidade, vamos calcular a quantidade de trocas
resultado = quantidade * probabilidade
print("A quantidade de peças que serão trocadas é de, aproximadamente:",resultado,"baterias")
# Out:
# A quantidade de peças que serão trocadas é de, aproximadamente: 19.9 baterias

# %% [markdown]
# ## 4° Questão
# Uma fábrica de carros sabe que os motres de sua fabricação têm
# duração normal com média de 150.000 km e desvio padrão de 5.000
# km. Qual a probabilidade de que um carro, escolhido ao acaso, dos
# fabricados por essa firma, tenha um motor que dure:

# %%
media = 150000
desvio = 5000
quantidade = 10000
numeros = np.random.normal(media,desvio,quantidade)
# Agora plotando a distribuição dos dados
sns.distplot(numeros, hist=False,rug=False)
plt.title('Distribuição Normal')
plt.xlim(120000,180000)
plt.axvline(media,color='k')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# * menos de 170.000 km?

# %%
zscore = (170000 - media)/desvio
# Sabendo que Z = 4, devemos considerar 3.99, logo o valor na tabela é 0.99997
possibilidade = 0.99997 * 100
print("As chances são de, aproximadamente",possibilidade,"%")
# Out:
# As chances são de, aproximadamente 99.997 %

# %% [markdown]
# * entre 140.000 km e 165.000 km?

# %%
# Descobrindo o ZScore
zscore1 = (140000 - media)/desvio
zscore2 = (165000 - media)/desvio
# O zscore1(-2.0) é equivalente a 0.02275 na tabela
# O zscore2(3.0) é equivalente a 0.99865 na tabela
prob1 = 0.02275
prob2 = 0.99865
# Agora é só subtrair para descobrir a área no intervalo
resultado = (prob2 - prob1) * 100
print("As chances são de, aproximadamente:",resultado,"%")
# Out:
# As chances são de, aproximadamente: 97.59 %

# %% [markdown]
# * Se a fábrica substituir o motor que apresenta duração inferior à
# garantia, qual deve ser esta garantia para que a porcentagem de
# motores substituı́dos seja inferior a 0,2%?

# %%
porcentagem = 0.2/100
# Olhamos o valor mais próximo de 0.002 na tabela, ou seja, 0.00205 (-2.87)
# Convertendo para Z
x = (-2.87 * desvio) + media
print("A garantia tem de ser abaixo de, aproximadamente:",x,"km")
# Out:
# A garantia tem de ser abaixo de, aproximadamente: 135650.0 km

# %% [markdown]
# ## 5° Questão
# Uma fábrica de telas de TV determinou que a vida média das telas
# de sua fabricação é de 800 horas de uso contı́nuo e segue uma
# distribuição normal, com desvio padrão de 100 horas. Qual a
# probabilidade de que a fábrica tenha de substituir uma tela
# gratuitamente, se oferece uma garantia de 300 horas de uso?

# %%
media = 800
desvio = 100
quantidade = 1000
numeros = np.random.normal(media,desvio,quantidade)
# Agora plotando a distribuição dos dados
sns.distplot(numeros, hist=False,rug=False)
plt.title('Distribuição Normal')
plt.xlim(0,1500)
plt.axvline(media,color='k')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Depois dos dados gerados, fazemos o cálculo:

# %%
zscore = (300 - media)/desvio
# Sabendo que Z = -5, devemos considerar o menor valor da tabela já que excede o valores da mesma, logo o valor que usaremos é 	0.00003.
possibilidade = 	0.00003 * 100
print("As chances são de, aproximadamente",possibilidade,"%")
# Out:
# As chances são de, aproximadamente 0.003 %

# %% [markdown]
# ## 6° Questão
# Os salários de diretores de empresas de São Paulo distribuem-se
# normalmente com média de 8.000 reais e desvio padrão de 500 reais. Qual a porcentagem de diretores que recebem:

# %%
media = 8000
desvio = 500
quantidade = 1000
numeros = np.random.normal(media,desvio,quantidade)
# Agora plotando a distribuição dos dados
sns.distplot(numeros, hist=False,rug=False)
plt.title('Distribuição Normal')
plt.xlim(5000,11000)
plt.axvline(media,color='k')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# * menos de R$6.470,00?

# %%
# Descobrindo o ZScore
zscore = (6470 - media)/desvio
# Sabendo que Z = -3.06, logo o valor na tabela é 0.00111
possibilidade = 0.00111 * 100
print("As chances são de, aproximadamente",possibilidade,"%")
# Out:
# As chances são de, aproximadamente 0.11100000000000002 %

# %% [markdown]
# * entre 8920 reais e 9.380 reais?

# %%
# Descobrindo o ZScore
zscore1 = (8920 - media)/desvio
zscore2 = (9380 - media)/desvio
# O zscore1(1.84) é equivalente a 0.96712 na tabela
# O zscore2(2.76) é equivalente a 0.99711 na tabela
prob1 = 0.96712 
prob2 = 0.99711
# Agora é só subtrair para descobrir a área no intervalo
resultado = (prob2 - prob1) * 100
print("As chances são de, aproximadamente:",resultado,"%")
# Out:
# As chances são de, aproximadamente: 2.999000000000007 %

# %% [markdown]
# ## 7° Questão
#
# A quantidade de óleo contida em cada lata fabricada por uma
# indústria tem peso distribuı́do normalmente, com média de 990g e
# desvio padrão de 10g. Uma lata reéjeitada no comércio se tiver peso
# menor que 976g.

# %%
media = 990
desvio = 10
quantidade = 1000
numeros = np.random.normal(media,desvio,quantidade)
# Agora plotando a distribuição dos dados
sns.distplot(numeros, hist=False,rug=False)
plt.title('Distribuição Normal')
plt.xlim(900,1100)
plt.axvline(media,color='k')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# * Se observarmos uma sequência casual destas latas em uma linha de
# produção, qual a probabilidade de que a 10ª lata observada seja a
# primeira a ser rejeitada?

# %%
zscore = (976-media)/desvio
# O valor de zscore é -1.4 (0.08076)
probabilidade = 0.08076
print("A chance de uma lata ser rejeitada é de, aproximadamente:",resultado*100,"%")
#Chances de sucesso em 10 latas
chances = (1-probabilidade)**9
#Calcular as chances de fracasso
chances *= probabilidade
print("A probabilidade de rejeição será de, aproximadamente: ",chances, "%")
# Out:
# A chance de uma lata ser rejeitada é de, aproximadamente: 8.076 %
# A probabilidade de rejeição será:  0.03784918539804909 %

# %% [markdown]
# * Nas condições do item anterior, qual a probabilidade de que, em 20
# latas observadas, 3 sejam rejeitadas?

# %%
#Chances de sucesso em 20 latas
chances = (1-probabilidade)**17
#Calcular as chances de fracasso
resultado = chances*(probabilidade)**3
print("A probabilidade de rejeição será de, aproximadamente: ",resultado, "%")
# Out:
# A probabilidade de rejeição será de, aproximadamente:  0.00012585789680442133 %

# %% [markdown]
# ## 8ª Questão
# Um fabricante de produtos alimentı́cios vende um de seus produtos
# em latas de 900 g de conteúdo lı́quido. Para embalar o produto,
# adquiriu uma máquina que permite obter o peso desejado, com
# distribuição normal e desvio padrão de 10g. O IPM (Instituto de
# Pesos e Medidas) exige no máximo 5% das latas contenham menos
# do que o peso lı́quido nominal. Se a máquina for regulada para 910g,
# poderá satisfazer a exigência. Qual deverá ser a regulagem da
# máquina para que a exigência do IPM seja observada? Feita Esta
# nova regulagem, as latas são remetidas ao comércio. O IPM examina
# então uma amostra de 20 latas em um supermercado. Qual a
# probabilidade de encontrar pelo menos 3 com peso inferior ao
# especificado na embalagem?

# %%
media = 
desvio = 
quantidade = 
numeros = np.random.normal(media,desvio,quantidade)
# Agora plotando a distribuição dos dados
sns.distplot(numeros, hist=False,rug=False)
plt.title('Distribuição Normal')
plt.xlim(0,100)
plt.axvline(media,color='k')
plt.show()
